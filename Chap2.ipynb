# %% [markdown]
# # Chap2 流程控制

# %% [markdown]
# ## if else , elif

# %%
a=eval(input("請輸入數字a:"))
b=eval(input("請輸入數字b:"))
if a>b:
  print("a>b")
elif a==b:
  print("a=b")
else:
  print("b>a")
# Out:
# 請輸入數字a:1
# 請輸入數字b:2
# b>a

# %% [markdown]
# ### 成績評鑑

# %%
grade=87
print("成績評鑑:")
if grade>=90:
  print("優等")
elif grade>=80:
  print("甲等")
elif grade>=70:
  print("乙等")
elif grade>=60:
  print("丙等")
else:
  print("不及格")
# Out:
# 成績評鑑:
# 甲等

# %% [markdown]
# ## for 迴圈

# %%
for i in range(10):  #range(10):0,1，2，3，4，...，9
  print(i)
# Out:
# 1+2+3+...+10 = 55

# %%
for i in range(0,10,1): #range:從1開始，9結束，間隔1
  print(i)
# Out:
# 1+2+3+...+10 = 55

# %%
sum=0
for count in range(1,11,1):  
  sum+=count
print(sum)
# Out:
# 55

# %%
for c in "I am a boy":
  print(c)
# Out:
# I
#
# a
# m
#
# a
#
# b
# o
# y

# %%
for score in [90,100,88,77]:
  print(score)
# Out:
# 90
# 100
# 88
# 77

# %%
for s in ["john","mary","tom","simpson"]:
  print(s)
# Out:
# john
# mary
# tom
# simpson

# %% [markdown]
# ### 雞兔同籠，若共有35個頭，94隻腳，請問有幾隻雞?幾隻兔?

# %%
for chicken in range(0,36):
  rabbit=35-chicken
  if(2*chicken+4*rabbit) == 94:
    print("雞有",chicken,"隻,兔子有",rabbit,"隻")
    break
else:
  print("無解")
# Out:
# 雞有 23 隻,兔子有 12 隻

# %%
sum=0
count=1
while count <=10:
    sum+=count
    count+=1
print("1+2+3+...+10=",sum)
# Out:
# 1+2+3+...+10= 55
